# %% [markdown]
# # Robust Object Detection System

# %% [markdown]
# ### Task:
# - Classify coins and test under difficult conditions.
# - Evaluate performance under: blurred, low-light, and low-resolution conditions.
#
# ### Preparations Stages:
# 1. Modify YOLOv5 for multi-class detection.
# 2. Train model for detection and classification of coins.
# 3. Simulate hard conditions using image transformations.
# 4. Test and compare model performance under these conditions.
#
# ### Evaluation Goals:
# - Intersection over Union (IoU) - for localization accuracy.
# - Robustness under challenging conditions (blurred, low-light, low-resolution).
# - Recall and Precision - for classification accuracy.

# %%
# TODO: 1. Use coin dataset for training and testing ( see RobotDreams final project for dataset link)
# TODO: 2. Use new assembled PC to do this notebook, as it requires GPU for training and testing.
