# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("bastianberle/eurocoins-images-object-detection",
                                  output_dir='datasets/eurocoins-images-object-detection')

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 192M/192M [00:21<00:00, 9.17MB/s]
# Extracting files...
# Path to dataset files: datasets/eurocoins-images-object-detection
