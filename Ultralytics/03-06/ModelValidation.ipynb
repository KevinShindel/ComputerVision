# %% [markdown]
# # YOLOv8

# %%
import json

from ultralytics import YOLO

# %% [markdown]
# load model

# %%
model = YOLO("best-segment.pt")

# %% [markdown]
# model validation

# %%
metrics = model.val(
    data="data.yaml"
)
# Out:
# Ultralytics 8.4.99  Python-3.13.13 torch-2.13.0+cpu CPU (11th Gen Intel Core i7-1185G7 @ 3.00GHz)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 11.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1523.713.8 MB/s, size: 700.5 KB)
# val: Scanning C:\Users\TymurHilfatullin\Projects\ComputerVision\Ultralytics\03-06\dataset\val\labels... 2 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2/2 46.9it/s 0.0s
# val: New cache created: C:\Users\TymurHilfatullin\Projects\ComputerVision\Ultralytics\03-06\dataset\val\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.5it/s 0.4s
#                    all          2        249          1      0.987      0.995      0.956      0.984       0.97      0.978       0.83
# Speed: 0.9ms preprocess, 80.7ms inference, 0.0ms loss, 15.0ms postprocess per image
# Results saved to C:\Users\TymurHilfatullin\Projects\ComputerVision\runs\segment\val-2

# %% [markdown]
# metrics extraction

# %%
metrics_dict = metrics.results_dict
json_dump = json.dumps(metrics_dict, indent=4, sort_keys=True)
print(json_dump)

# save metrics to a json file
with open("metrics.json", "w") as f:
    f.write(json_dump)
# Out:
# {
#     "metrics/precision(B)": 1.0,
#     "metrics/recall(B)": 0.9865545307975143,
#     "metrics/mAP50(B)": 0.9948418972332015,
#     "metrics/mAP50-95(B)": 0.9560141882793953,
#     "metrics/precision(M)": 0.9837167465185719,
#     "metrics/recall(M)": 0.9704902737694019,
#     "metrics/mAP50(M)": 0.9780757043186236,
#     "metrics/mAP50-95(M)": 0.8296196948466745,
#     "fitness": 1.7856338831260699
# }
